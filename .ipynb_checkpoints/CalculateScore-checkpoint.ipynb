# %%
import pandas as pd

# %%
oldPath = "data/2019Q2.csv"
currentPath = "data/2020Q2.csv"

oldData = pd.read_csv(oldPath)
currentData = pd.read_csv(currentPath)

# %%
currentData[currentData['symbol'] == 'AAPL']['symbol']
# Out:
# 349    AAPL
# Name: symbol, dtype: object

# %%
def calculate_score(symbol):
    # Get relevant values
    row = currentData.loc[currentData['symbol'] == 'AAPL'].to_dict("records")[0]
    net_income = row['ic-NetIncomeLoss']
    total_assets = row['bs-Assets']
    print(net_income)
    print(total_assets)
    return row
    
    
    # Return on assets

    
    
    
calculate_score('AAPL')
# Out:
# 11249000000.0
# 320400000000.0
# {'Unnamed: 0': 349,
#  'accessNumber': '0000320193-20-000052.json',
#  'bs-AccountsAndNotesReceivableNet': nan,
#  'bs-AccountsAndOtherReceivablesNetCurrent': nan,
#  'bs-AccountsNotesAndLoansReceivableNetCurrent': nan,
#  'bs-AccountsPayableAndAccruedLiabilitiesCurrent': nan,
#  'bs-AccountsPayableAndAccruedLiabilitiesCurrentAndNoncurrent': nan,
#  'bs-AccountsPayableAndAccruedLiabilitiesFairValueDisclosure': nan,
#  'bs-AccountsPayableAndAccruedLiabilitiesNoncurrent': nan,
#  'bs-AccountsPayableAndOtherAccruedLiabilities': nan,
#  'bs-AccountsPayableAndOtherAccruedLiabilitiesCurrent': nan,
#  'bs-AccountsPayableCurrent': 32421000000.0,
#  'bs-AccountsPayableCurrentAndNoncurrent': nan,
#  'bs-AccountsPayableOtherCurrent': nan,
#  'bs-AccountsPayableOtherCurrentAndNoncurrent': nan,
#  'bs-AccountsPayableRelatedPartiesCurrent': nan,
#  'bs-AccountsPayableRelatedPartiesCurrentAndNoncurrent': nan,
#  'bs-AccountsPayableRelatedPartiesNoncurrent': nan,
#  'bs-AccountsPayableTradeCurrent': nan,
#  'bs-AccountsPayableTradeCurrentAndNoncurrent': nan,
#  'bs-AccountsPayableUnderwritersPromotersAndEmployeesOtherThanSalariesAndWagesCurrent': nan,
#  'bs-AccountsReceivableBilledForLongTermContractsOrPrograms': nan,
#  'bs-AccountsReceivableChangeInMethodCreditLossExpenseReversal': nan,
#  'bs-AccountsReceivableFromSecuritization': nan,
#  'bs-AccountsReceivableGross': nan,
#  'bs-AccountsReceivableGrossCurrent': nan,
#  'bs-AccountsReceivableGrossNoncurrent': nan,
#  'bs-AccountsReceivableNet': nan,
#  'bs-AccountsReceivableNetCurrent': 15722000000.0,
#  'bs-AccountsReceivableNetNoncurrent': nan,
#  'bs-AccountsReceivableRelatedParties': nan,
#  'bs-AccountsReceivableRelatedPartiesCurrent': nan,
#  'bs-AccountsReceivableRelatedPartiesNoncurrent': nan,
#  'bs-AccretionAmortizationOfDiscountsAndPremiumsInvestments': nan,
#  'bs-AccretionExpense': nan,
#  'bs-AccretionExpenseIncludingAssetRetirementObligations': nan,
#  'bs-AccrualForEnvironmentalLossContingencies': nan,
#  'bs-AccrualForTaxesOtherThanIncomeTaxesCurrent': nan,
#  'bs-AccrualForTaxesOtherThanIncomeTaxesCurrentAndNoncurrent': nan,
#  'bs-AccruedAdvertisingCurrent': nan,
#  'bs-AccruedBonusesCurrent': nan,
#  'bs-AccruedBonusesCurrentAndNoncurrent': nan,
#  'bs-AccruedCappingClosurePostClosureAndEnvironmentalCosts': nan,
#  'bs-AccruedCappingClosurePostClosureAndEnvironmentalCostsNoncurrent': nan,
#  'bs-AccruedEmployeeBenefitsCurrent': nan,
#  'bs-AccruedEmployeeBenefitsCurrentAndNoncurrent': nan,
#  'bs-AccruedEnvironmentalLossContingenciesCurrent': nan,
#  'bs-AccruedEnvironmentalLossContingenciesNoncurrent': nan,
#  'bs-AccruedFeesAndOtherRevenueReceivable': nan,
#  'bs-AccruedIncomeTaxes': nan,
#  'bs-AccruedIncomeTaxesCurrent': nan,
#  'bs-AccruedIncomeTaxesNoncurrent': nan,
#  'bs-AccruedInsuranceCurrent': nan,
#  'bs-AccruedInsuranceNoncurrent': nan,
#  'bs-AccruedInvestmentIncomeReceivable': nan,
#  'bs-AccruedLiabilitiesAndOtherLiabilities': nan,
#  'bs-AccruedLiabilitiesCurrent': nan,
#  'bs-AccruedLiabilitiesCurrentAndNoncurrent': nan,
#  'bs-AccruedLiabilitiesFairValueDisclosure': nan,
#  'bs-AccruedLiabilitiesForUnredeeemedGiftCards': nan,
#  'bs-AccruedMarketingCostsCurrent': nan,
#  'bs-AccruedPayrollTaxesCurrent': nan,
#  'bs-AccruedPayrollTaxesCurrentAndNoncurrent': nan,
#  'bs-AccruedProfessionalFeesCurrent': nan,
#  'bs-AccruedProfessionalFeesCurrentAndNoncurrent': nan,
#  'bs-AccruedReclamationCostsCurrent': nan,
#  'bs-AccruedRentCurrent': nan,
#  'bs-AccruedRentCurrentAndNoncurrent': nan,
#  'bs-AccruedRoyaltiesCurrent': nan,
#  'bs-AccruedRoyaltiesCurrentAndNoncurrent': nan,
#  'bs-AccruedSalariesCurrent': nan,
#  'bs-AccruedSalariesCurrentAndNoncurrent': nan,
#  'bs-AccruedSalesCommissionCurrent': nan,
#  'bs-AccruedSalesCommissionCurrentAndNoncurrent': nan,
#  'bs-AccruedUtilitiesCurrent': nan,
#  'bs-AccruedVacationCurrent': nan,
#  'bs-AccumulatedDeferredInvestmentTaxCredit': nan,
#  'bs-AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment': nan,
#  'bs-AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipmentExcludingCapitalLeasedAssets': nan,
#  'bs-AccumulatedDistributionsInExcessOfNetIncome': nan,
#  'bs-AccumulatedOtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax': nan,
#  'bs-AccumulatedOtherComprehensiveIncomeLossBeforeFederalHomeLoanBankAssessments': nan,
#  'bs-AccumulatedOtherComprehensiveIncomeLossBeforeTax1': nan,
#  'bs-AccumulatedOtherComprehensiveIncomeLossCumulativeChangesInNetGainLossFromCashFlowHedgesEffectNetOfTax': nan,
#  'bs-AccumulatedOtherComprehensiveIncomeLossDefinedBenefitPensionAndOtherPostretirementPlansNetOfTax': nan,
#  'bs-AccumulatedOtherComprehensiveIncomeLossForeignCurrencyTranslationAdjustmentNetOfTax': nan,
#  'bs-AccumulatedOtherComprehensiveIncomeLossNetOfTax': 2789000000.0,
#  'bs-AcquisitionCosts': nan,
#  'bs-AcquisitionCostsCumulative': nan,
#  'bs-AdditionalPaidInCapital': nan,
#  'bs-AdditionalPaidInCapitalCommonStock': nan,
#  'bs-AdditionalPaidInCapitalPreferredStock': nan,
#  'bs-AdditionsToContractHoldersFunds': nan,
#  'bs-AdjustmentForAmortization': nan,
#  'bs-AdjustmentOfWarrantsGrantedForServices': nan,
#  'bs-AdjustmentsNoncashItemsToReconcileNetIncomeLossToCashProvidedByUsedInOperatingActivities': nan,
#  'bs-AdjustmentsRelatedToTaxWithholdingForShareBasedCompensation': nan,
#  'bs-AdjustmentsToAdditionalPaidInCapitalConvertibleDebtWithConversionFeature': nan,
#  'bs-AdjustmentsToAdditionalPaidInCapitalMarkToMarket': nan,
#  'bs-AdjustmentsToAdditionalPaidInCapitalOther': nan,
#  'bs-AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationOtherLongtermIncentivePlansRequisiteServicePeriodRecognition': nan,
#  'bs-AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationRequisiteServicePeriodRecognitionValue': nan,
#  'bs-AdjustmentsToAdditionalPaidInCapitalWarrantIssued': nan,
#  'bs-AdjustmentsToReconcileNetIncomeLossToCashProvidedByUsedInOperatingActivities': nan,
#  'bs-AdvancePaymentsByBorrowersForTaxesAndInsurance': nan,
#  'bs-AdvanceRent': nan,
#  'bs-AdvanceRoyaltiesCurrent': nan,
#  'bs-AdvanceRoyaltiesNoncurrent': nan,
#  'bs-AdvancesFairValueDisclosure': nan,
#  'bs-AdvancesFromFederalHomeLoanBanks': nan,
#  'bs-AdvancesOnInventoryPurchases': nan,
#  'bs-AdvancesToAffiliate': nan,
#  'bs-AdvertisingExpense': nan,
#  'bs-AffordableHousingProgramObligation': nan,
#  'bs-AirlineRelatedInventoryNet': nan,
#  'bs-AllocatedShareBasedCompensationExpense': nan,
#  'bs-AllocatedShareBasedCompensationExpenseNetOfTax': nan,
#  'bs-AllowanceForDoubtfulAccountsPremiumsAndOtherReceivables': nan,
#  'bs-AllowanceForDoubtfulAccountsReceivable': nan,
#  'bs-AllowanceForDoubtfulAccountsReceivableCurrent': nan,
#  'bs-AllowanceForDoubtfulAccountsReceivablePeriodIncreaseDecrease': nan,
#  'bs-AllowanceForDoubtfulAccountsReceivableRecoveries': nan,
#  'bs-AllowanceForDoubtfulAccountsReceivableWriteOffs': nan,
#  'bs-AllowanceForFundsUsedDuringConstructionInvestingActivities': nan,
#  'bs-AllowanceForLoanAndLeaseLossRecoveryOfBadDebts': nan,
#  'bs-AllowanceForLoanAndLeaseLossesRealEstate': nan,
#  'bs-AllowanceForLoanAndLeaseLossesWriteOffs': nan,
#  'bs-AllowanceForLoanAndLeaseLossesWriteoffsNet': nan,
#  'bs-AllowanceForNotesAndLoansReceivableCurrent': nan,
#  'bs-AllowanceForNotesAndLoansReceivableNoncurrent': nan,
#  'bs-AlternativeInvestment': nan,
#  'bs-AmortizationAndDepreciationOfDecontaminatingAndDecommissioningAssets': nan,
#  'bs-AmortizationMethodQualifiedAffordableHousingProjectInvestments': nan,
#  'bs-AmortizationMethodQualifiedAffordableHousingProjectInvestmentsAmortization': nan,
#  'bs-AmortizationOfAboveAndBelowMarketLeases': nan,
#  'bs-AmortizationOfAcquisitionCosts': nan,
#  'bs-AmortizationOfAdvanceRoyalty': nan,
#  'bs-AmortizationOfBelowMarketLease': nan,
#  'bs-AmortizationOfDebtDiscountPremium': nan,
#  'bs-AmortizationOfDeferredCharges': nan,
#  'bs-AmortizationOfDeferredHedgeGains': nan,
#  'bs-AmortizationOfDeferredLeasingFees': nan,
#  'bs-AmortizationOfDeferredLoanOriginationFeesNet': nan,
#  'bs-AmortizationOfDeferredPropertyTaxes': nan,
#  'bs-AmortizationOfDeferredSalesCommissions': nan,
#  'bs-AmortizationOfFinancingCosts': nan,
#  'bs-AmortizationOfFinancingCostsAndDiscounts': nan,
#  'bs-AmortizationOfIntangibleAssets': nan,
#  'bs-AmortizationOfLeaseIncentives': nan,
#  'bs-AmortizationOfLeasedAsset': nan,
#  'bs-AmortizationOfMortgageServicingRightsMSRs': nan,
#  'bs-AmortizationOfNuclearFuelLease': nan,
#  'bs-AmortizationOfPowerContractsEmissionCredits': nan,
#  'bs-AmortizationOfRegulatoryAsset': nan,
#  'bs-AmortizationOfValueOfBusinessAcquiredVOBA': nan,
#  'bs-AociBeforeTaxAttributableToParent': nan,
#  'bs-AociDebtSecuritiesAvailableForSaleWithAllowanceForCreditLossCumulativeGainLossAfterTax': nan,
#  'bs-AociLossCashFlowHedgeCumulativeGainLossAfterTax': nan,
#  'bs-AociTaxAttributableToParent': nan,
#  'bs-AssetImpairmentCharges': nan,
#  'bs-AssetRetirementObligation': nan,
#  'bs-AssetRetirementObligationAccretionExpense': nan,
#  'bs-AssetRetirementObligationCashPaidToSettle': nan,
#  'bs-AssetRetirementObligationCurrent': nan,
#  'bs-AssetRetirementObligationLiabilitiesIncurred': nan,
#  'bs-AssetRetirementObligationPeriodIncreaseDecrease': nan,
#  'bs-AssetRetirementObligationRevisionOfEstimate': nan,
#  'bs-AssetRetirementObligationsNoncurrent': nan,
#  'bs-Assets': 320400000000.0,
#  'bs-AssetsCurrent': 143753000000.0,
#  'bs-AssetsDisposedOfByMethodOtherThanSaleInPeriodOfDispositionGainLossOnDisposition1': nan,
#  'bs-AssetsFairValueAdjustment': nan,
#  'bs-AssetsFairValueDisclosure': nan,
#  'bs-AssetsHeldForSaleLongLivedFairValueDisclosure': nan,
#  'bs-AssetsHeldForSaleNotPartOfDisposalGroup': nan,
#  'bs-AssetsHeldForSaleNotPartOfDisposalGroupCurrent': nan,
#  'bs-AssetsHeldForSaleNotPartOfDisposalGroupCurrentOther': nan,
#  'bs-AssetsHeldForSaleNotPartOfDisposalGroupOther': nan,
#  'bs-AssetsHeldInTrust': nan,
#  'bs-AssetsHeldInTrustCurrent': nan,
#  'bs-AssetsHeldInTrustNoncurrent': nan,
#  'bs-AssetsNet': nan,
#  'bs-AssetsNoncurrent': 176647000000.0,
#  'bs-AssetsNoncurrentOtherThanNoncurrentInvestmentsAndPropertyPlantAndEquipment': nan,
#  'bs-AssetsOfDisposalGroupIncludingDiscontinuedOperation': nan,
#  'bs-AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent': nan,
#  'bs-AvailableForSaleDebtSecuritiesGrossUnrealizedLoss': nan,
#  'bs-AvailableForSaleEquitySecuritiesGrossUnrealizedGain': nan,
#  'bs-AvailableForSaleEquitySecuritiesGrossUnrealizedLoss': nan,
#  'bs-AvailableForSaleSecurities': nan,
#  'bs-AvailableForSaleSecuritiesCurrent': nan,
#  'bs-AvailableForSaleSecuritiesDebtSecurities': nan,
#  'bs-AvailableForSaleSecuritiesDebtSecuritiesCurrent': nan,
#  'bs-AvailableForSaleSecuritiesDebtSecuritiesNoncurrent': nan,
#  'bs-AvailableForSaleSecuritiesEquitySecurities': nan,
#  'bs-AvailableForSaleSecuritiesEquitySecuritiesCurrent': nan,
#  'bs-AvailableForSaleSecuritiesEquitySecuritiesNoncurrent': nan,
#  'bs-AvailableForSaleSecuritiesGrossRealizedGainLossNet': nan,
#  'bs-AvailableForSaleSecuritiesGrossUnrealizedLoss': nan,
#  'bs-AvailableForSaleSecuritiesNoncurrent': nan,
#  'bs-AvailableForSaleSecuritiesTransfersToTradingGainsLossesNet': nan,
#  'bs-AvailableForSaleSecuritiesTransfersToTradingGrossGains': nan,
#  'bs-AvailableforsaleSecuritiesGrossRealizedGainLossExcludingOtherThanTemporaryImpairments': nan,
#  'bs-BankAcceptancesExecutedAndOutstanding': nan,
#  'bs-BankOverdrafts': nan,
#  'bs-BankOwnedLifeInsurance': nan,
#  'bs-BankOwnedLifeInsuranceIncome': nan,
#  'bs-BelowMarketLeaseNet': nan,
#  'bs-BilledContractReceivables': nan,
#  'bs-BillingsInExcessOfCost': nan,
#  'bs-BillingsInExcessOfCostCurrent': nan,
#  'bs-BridgeLoan': nan,
#  'bs-BuildingsAndImprovementsGross': nan,
#  'bs-BusinessAcquisitionEquityInterestIssuedOrIssuableValueAssigned': nan,
#  'bs-BusinessAcquisitionPreacquisitionContingencyAmountOfSettlement': nan,
#  'bs-BusinessAcquisitionsPurchasePriceAllocationYearOfAcquisitionNetEffectOnIncome': nan,
#  'bs-BusinessCombinationAcquisitionOfLessThan100PercentNoncontrollingInterestFairValue': nan,
#  'bs-BusinessCombinationAcquisitionRelatedCosts': nan,
#  'bs-BusinessCombinationBargainPurchaseGainRecognizedAmount': nan,
#  'bs-BusinessCombinationConsiderationTransferred1': nan,
#  'bs-BusinessCombinationConsiderationTransferredEquityInterestsIssuedAndIssuable': nan,
#  'bs-BusinessCombinationConsiderationTransferredLiabilitiesIncurred': nan,
#  'bs-BusinessCombinationConsiderationTransferredOther1': nan,
#  'bs-BusinessCombinationContingentConsiderationArrangementsChangeInAmountOfContingentConsiderationAsset1': nan,
#  'bs-BusinessCombinationContingentConsiderationArrangementsChangeInAmountOfContingentConsiderationLiability1': nan,
#  'bs-BusinessCombinationContingentConsiderationArrangementsChangeInTheRangeOfOutcomesContingentConsiderationLiabilityValueLow': nan,
#  'bs-BusinessCombinationContingentConsiderationAssetNoncurrent': nan,
#  'bs-BusinessCombinationContingentConsiderationLiability': nan,
#  'bs-BusinessCombinationContingentConsiderationLiabilityCurrent': nan,
#  'bs-BusinessCombinationContingentConsiderationLiabilityNoncurrent': nan,
#  'bs-BusinessCombinationLiabilitiesArisingFromContingenciesAmountRecognized': nan,
#  'bs-BusinessCombinationProvisionalInformationInitialAccountingIncompleteAdjustmentFinancialLiabilities': nan,
#  'bs-BusinessCombinationProvisionalInformationInitialAccountingIncompleteAdjustmentInventory': nan,
#  'bs-BusinessCombinationProvisionalInformationInitialAccountingIncompleteAdjustmentsRelatedToPreviousPeriod': nan,
#  'bs-BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCapitalLeaseObligation': nan,
#  'bs-BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedContingentLiability': nan,
#  'bs-BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCurrentAssetsPrepaidExpenseAndOtherAssets': nan,
#  'bs-BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCurrentLiabilitiesAccountsPayable': nan,
#  'bs-BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedEquipment': nan,
#  'bs-BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedIntangibleAssetsOtherThanGoodwill': nan,
#  'bs-BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedNet': nan,
#  'bs-BusinessCombinationStepAcquisitionEquityInterestInAcquireeRemeasurementGain': nan,
#  'bs-BusinessCombinationStepAcquisitionEquityInterestInAcquireeRemeasurementGainOrLoss': nan,
#  'bs-BusinessExitCosts1': nan,
#  'bs-Capital': nan,
#  'bs-CapitalExpenditureDiscontinuedOperations': nan,
#  'bs-CapitalExpendituresIncurredButNotYetPaid': nan,
#  'bs-CapitalLeaseObligations': nan,
#  'bs-CapitalLeaseObligationsCurrent': nan,
#  'bs-CapitalLeaseObligationsIncurred': nan,
#  'bs-CapitalLeaseObligationsNoncurrent': nan,
#  'bs-CapitalLeasedAssetsGross': nan,
#  'bs-CapitalLeasesBalanceSheetAssetsByMajorClassNet': nan,
#  'bs-CapitalLeasesLessorBalanceSheetNetInvestmentInDirectFinancingAndSalesTypeLeasesCurrent': nan,
#  'bs-CapitalLeasesLessorBalanceSheetNetInvestmentInDirectFinancingAndSalesTypeLeasesNoncurrent': nan,
#  'bs-CapitalLeasesLessorBalanceSheetNetInvestmentInDirectFinancingLeasesNoncurrent': nan,
#  'bs-CapitalLeasesLessorBalanceSheetNetInvestmentInSalesTypeLeasesNoncurrent': nan,
#  'bs-CapitalLeasesNetInvestmentInDirectFinancingLeases': nan,
#  'bs-CapitalLeasesNetInvestmentInSalesTypeLeases': nan,
#  'bs-CapitalUnits': nan,
#  'bs-CapitalUnitsNetAmount': nan,
#  'bs-CapitalizationLongtermDebtAndEquity': nan,
#  'bs-CapitalizedComputerSoftwareAdditions': nan,
#  'bs-CapitalizedComputerSoftwareAmortization1': nan,
#  'bs-CapitalizedComputerSoftwareGross': nan,
#  'bs-CapitalizedComputerSoftwareImpairments1': nan,
#  'bs-CapitalizedComputerSoftwareNet': nan,
#  'bs-CapitalizedComputerSoftwarePeriodIncreaseDecrease': nan,
#  'bs-CapitalizedContractCostAmortization': nan,
#  'bs-CapitalizedContractCostGross': nan,
#  'bs-CapitalizedContractCostImpairmentLoss': nan,
#  'bs-CapitalizedContractCostNet': nan,
#  'bs-CapitalizedContractCostNetCurrent': nan,
#  'bs-CapitalizedContractCostNetNoncurrent': nan,
#  'bs-CapitalizedCostsAccumulatedDepreciationDepletionAmortizationAndValuationAllowanceForRelatingToOilAndGasProducingActivities': nan,
#  'bs-CapitalizedCostsOfUnprovedPropertiesExcludedFromAmortization': nan,
#  'bs-CapitalizedCostsOfUnprovedPropertiesExcludedFromAmortizationCumulative': nan,
#  'bs-CapitalizedCostsOilAndGasProducingActivitiesNet': nan,
#  'bs-CapitalizedCostsProvedProperties': nan,
#  'bs-CapitalizedCostsSupportEquipmentAndFacilities': nan,
#  'bs-CapitalizedCostsUncompletedWellsEquipmentAndFacilities': nan,
#  'bs-CapitalizedCostsUnprovedProperties': nan,
#  'bs-CapitalizedExploratoryWellCostChargedToExpense1': nan,
#  'bs-CapitalizedSoftwareDevelopmentCostsForSoftwareSoldToCustomers': nan,
#  'bs-CarryingValueOfFederalFundsPurchasedSecuritiesSoldUnderAgreementsToRepurchaseAndDepositsReceivedForSecuritiesLoaned': nan,
#  'bs-CarryingValueOfFederalFundsSoldSecuritiesPurchasedUnderAgreementsToResellAndDepositsPaidForSecuritiesBorrowed': nan,
#  'bs-Cash': nan,
#  'bs-CashAcquiredFromAcquisition': nan,
#  'bs-CashAcquiredInExcessOfPaymentsToAcquireBusiness': nan,
#  'bs-CashAndCashEquivalentsAtCarryingValue': nan,
#  'bs-CashAndCashEquivalentsAtCarryingValueIncludingDiscontinuedOperations': nan,
#  'bs-CashAndCashEquivalentsFairValueDisclosure': nan,
#  'bs-CashAndCashEquivalentsPeriodIncreaseDecrease': nan,
#  'bs-CashAndCashEquivalentsPeriodIncreaseDecreaseExcludingExchangeRateEffect': nan,
#  'bs-CashAndDueFromBanks': nan,
#  'bs-CashAndSecuritiesSegregatedUnderFederalAndOtherRegulations': nan,
#  'bs-CashCashEquivalentsAndFederalFundsSold': nan,
#  'bs-CashCashEquivalentsAndShortTermInvestments': nan,
#  'bs-CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents': nan,
#  'bs-CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsDisposalGroupIncludingDiscontinuedOperations': nan,
#  'bs-CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations': nan,
#  'bs-CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseExcludingExchangeRateEffect': nan,
#  'bs-CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect': nan,
#  'bs-CashCollateralForBorrowedSecurities': nan,
#  'bs-CashDivestedFromDeconsolidation': nan,
#  'bs-CashDividendsPaidToParentCompany': nan,
#  'bs-CashDividendsPaidToParentCompanyBy50PercentOrLessOwnedPersons': nan,
#  'bs-CashDividendsPaidToParentCompanyByUnconsolidatedSubsidiaries': nan,
#  'bs-CashEquivalentsAtCarryingValue': nan,
#  'bs-CashPeriodIncreaseDecrease': nan,
#  'bs-CashPeriodIncreaseDecreaseExcludingExchangeRateEffect': nan,
#  'bs-CashProvidedByUsedInFinancingActivitiesDiscontinuedOperations': nan,
#  'bs-CashProvidedByUsedInInvestingActivitiesDiscontinuedOperations': nan,
#  'bs-CashProvidedByUsedInOperatingActivitiesDiscontinuedOperations': nan,
#  'bs-CashSegregatedUnderCommodityExchangeActRegulation': nan,
#  'bs-CashSegregatedUnderOtherRegulations': nan,
#  'bs-CashSurrenderValueFairValueDisclosure': nan,
#  'bs-CashSurrenderValueOfLifeInsurance': nan,
#  'bs-CededPremiumsPayable': nan,
#  'bs-CertainLoansAcquiredInTransferAccountedForAsDebtSecuritiesAccretableYieldAccretion': nan,
#  'bs-CertainLoansAcquiredInTransferNotAccountedForAsDebtSecuritiesAccretableYieldAccretion': nan,
#  'bs-CertainLoansAcquiredInTransferNotAccountedForAsDebtSecuritiesCarryingAmountNet': nan,
#  'bs-CertainLoansAcquiredInTransferNotAccountedForAsDebtSecuritiesOutstandingBalance': nan,
#  'bs-CertificatesOfDepositAtCarryingValue': nan,
#  'bs-ChangeInUnrealizedGainLossOnFairValueHedgingInstruments1': nan,
#  'bs-ChangeInUnrealizedGainLossOnHedgedItemInFairValueHedge1': nan,
#  'bs-ClassOfWarrantOrRightOutstanding': nan,
#  'bs-CollateralizedFinancings': nan,
#  'bs-CommercialPaper': nan,
#  'bs-CommissionsAndFloorBrokerageReceivables': nan,
#  'bs-CommissionsPayableToBrokerDealersAndClearingOrganizations': nan,
#  'bs-CommitmentsAndContingencies': nan,
#  'bs-CommodityContractAssetCurrent': nan,
#  'bs-CommodityContractAssetNoncurrent': nan,
#  'bs-CommonStockDiscountOnShares': nan,
#  'bs-CommonStockDividendsPerShareCashPaid': nan,
#  'bs-CommonStockDividendsPerShareDeclared': nan,
#  'bs-CommonStockHeldInTrust': nan,
#  'bs-CommonStockIssuedEmployeeStockTrust': nan,
#  'bs-CommonStockIssuedEmployeeTrustDeferred': nan,
#  'bs-CommonStockNoParValue': nan,
#  'bs-CommonStockOtherValueOutstanding': nan,
#  'bs-CommonStockParOrStatedValuePerShare': nan,
#  'bs-CommonStockShareSubscribedButUnissuedSubscriptionsReceivable': nan,
#  'bs-CommonStockSharesAuthorized': nan,
#  'bs-CommonStockSharesHeldInEmployeeTrust': nan,
#  'bs-CommonStockSharesHeldInEmployeeTrustShares': nan,
#  'bs-CommonStockSharesIssued': nan,
#  'bs-CommonStockSharesOutstanding': nan,
#  'bs-CommonStockSharesSubscribedButUnissued': nan,
#  'bs-CommonStockSharesSubscriptions': nan,
#  'bs-CommonStockValue': nan,
#  'bs-CommonStockValueOutstanding': nan,
#  'bs-CommonStocksIncludingAdditionalPaidInCapital': 48032000000.0,
#  'bs-CommonUnitIssuanceValue': nan,
#  'bs-CommonUnitOutstanding': nan,
#  'bs-CompensatedAbsencesLiability': nan,
#  'bs-CompensationAndBenefitsTrust': nan,
#  'bs-ComprehensiveIncomeNetOfTax': nan,
#  'bs-ConsiderationReceivedForBeneficialInterestObtainedForTransferringFinancialAsset': nan,
#  'bs-ConstructionInProgressExpendituresIncurredButNotYetPaid': nan,
#  'bs-ConstructionInProgressGross': nan,
#  'bs-ConstructionLoan': nan,
#  'bs-ConstructionPayableCurrent': nan,
#  'bs-ConstructionPayableCurrentAndNoncurrent': nan,
#  'bs-ContinuingInvolvementWithTransferredFinancialAssetsPrincipalAmountOutstanding': nan,
#  'bs-ContractReceivableRetainage': nan,
#  'bs-ContractReceivableRetainageDueAfterOneYear': nan,
#  'bs-ContractWithCustomerAssetCreditLossExpense': nan,
#  'bs-ContractWithCustomerAssetGross': nan,
#  'bs-ContractWithCustomerAssetGrossCurrent': nan,
#  'bs-ContractWithCustomerAssetGrossNoncurrent': nan,
#  'bs-ContractWithCustomerAssetIncreaseDecreaseForContractAcquiredInBusinessCombination': nan,
#  'bs-ContractWithCustomerAssetNet': nan,
#  'bs-ContractWithCustomerAssetNetCurrent': nan,
#  'bs-ContractWithCustomerAssetNetNoncurrent': nan,
#  'bs-ContractWithCustomerAssetReclassifiedToReceivable': nan,
#  'bs-ContractWithCustomerLiability': nan,
#  'bs-ContractWithCustomerLiabilityCurrent': 5928000000.0,
#  'bs-ContractWithCustomerLiabilityNoncurrent': nan,
#  'bs-ContractWithCustomerLiabilityRevenueRecognized': nan,
#  'bs-ContractWithCustomerPerformanceObligationSatisfiedInPreviousPeriod': nan,
#  'bs-ContractWithCustomerRefundLiability': nan,
#  'bs-ContractWithCustomerRefundLiabilityCurrent': nan,
#  'bs-ContractualObligation': nan,
#  'bs-ContributionOfProperty': nan,
#  'bs-ContributionsInAidOfConstruction': nan,
#  'bs-ConversionGainsAndLossesOnForeignInvestments': nan,
#  'bs-ConversionOfStockAmountConverted1': nan,
#  'bs-ConversionOfStockAmountIssued1': nan,
#  'bs-ConversionOfStockSharesConverted1': nan,
#  'bs-ConversionOfStockSharesIssued1': nan,
#  'bs-ConvertibleDebt': nan,
#  'bs-ConvertibleDebtCurrent': nan,
#  'bs-ConvertibleDebtFairValueDisclosures': nan,
#  'bs-ConvertibleDebtNoncurrent': nan,
#  'bs-ConvertibleLongTermNotesPayable': nan,
#  'bs-ConvertibleNotesPayable': nan,
#  'bs-ConvertibleNotesPayableCurrent': nan,
#  'bs-ConvertiblePreferredStockConvertedToOtherSecurities': nan,
#  'bs-ConvertiblePreferredStockNonredeemableOrRedeemableIssuerOptionValue': nan,
#  'bs-ConvertibleSubordinatedDebt': nan,
#  'bs-ConvertibleSubordinatedDebtNoncurrent': nan,
#  'bs-CostDepreciationAmortizationAndDepletion': nan,
#  'bs-CostMethodInvestments': nan,
#  'bs-CostMethodInvestmentsOriginalCost': nan,
#  'bs-CostMethodInvestmentsRealizedGainLoss': nan,
#  'bs-CostOfGoodsAndServicesSoldAmortization': nan,
#  'bs-CostOfGoodsAndServicesSoldDepreciation': nan,
#  'bs-CostOfGoodsAndServicesSoldDepreciationAndAmortization': nan,
#  'bs-CostOfGoodsSoldSalesTypeLease': nan,
#  'bs-CostmethodInvestmentsOtherThanTemporaryImpairment': nan,
#  'bs-CostmethodInvestmentsRealizedGainLossExcludingOtherThanTemporaryImpairments': nan,
#  'bs-CostsAndExpenses': nan,
#  'bs-CostsAndExpensesRelatedParty': nan,
#  'bs-CostsInExcessOfBillingsOnUncompletedContractsOrPrograms': nan,
#  'bs-CostsInExcessOfBillingsOnUncompletedContractsOrProgramsExpectedToBeCollectedWithinOneYear': nan,
#  'bs-CostsIncurredAssetRetirementObligationIncurred': nan,
#  'bs-CreditRiskDerivativeLiabilitiesAtFairValue': nan,
#  'bs-CumulativeDividends': nan,
#  'bs-CumulativeEarningsDeficit': nan,
#  'bs-CumulativeEffectOfNewAccountingPrincipleInPeriodOfAdoption': nan,
#  'bs-CumulativeEffectOnRetainedEarningsNetOfTax1': nan,
#  'bs-CurrentIncomeTaxExpenseBenefit': nan,
#  'bs-CustomerAdvancesAndDeposits': nan,
#  'bs-CustomerAdvancesAndDepositsCurrent': nan,
#  'bs-CustomerAdvancesCurrent': nan,
#  'bs-CustomerAdvancesOrDepositsNoncurrent': nan,
#  'bs-CustomerDepositsCurrent': nan,
#  'bs-CustomerDepositsNoncurrent': nan,
#  'bs-CustomerFunds': nan,
#  'bs-CustomerRefundLiabilityCurrent': nan,
#  'bs-CustomerRefundableFees': nan,
#  'bs-CustomerRefundableFeesPeriodIncreaseDecrease': nan,
#  'bs-CustomersLiabilityForAcceptancesNet': nan,
#  'bs-DebtAndCapitalLeaseObligations': nan,
#  'bs-DebtAndEquitySecuritiesGainLoss': nan,
#  'bs-DebtAndEquitySecuritiesRealizedGainLoss': nan,
#  'bs-DebtAndEquitySecuritiesUnrealizedGainLoss': nan,
#  'bs-DebtAndEquitySecuritiesUnrealizedGainLossExcludingOtherThanTemporaryImpairment': nan,
#  'bs-DebtConversionConvertedInstrumentAmount1': nan,
#  'bs-DebtConversionConvertedInstrumentSharesIssued1': nan,
#  'bs-DebtConversionOriginalDebtAmount1': nan,
#  'bs-DebtCurrent': nan,
#  'bs-DebtDefaultLongtermDebtAmount': nan,
#  'bs-DebtDefaultShorttermDebtAmount': nan,
#  'bs-DebtInstrumentCarryingAmount': nan,
#  'bs-DebtInstrumentConvertibleBeneficialConversionFeature': nan,
#  'bs-DebtInstrumentDecreaseForgiveness': nan,
#  'bs-DebtInstrumentFairValue': nan,
#  'bs-DebtInstrumentIncreaseAccruedInterest': nan,
#  'bs-DebtInstrumentIncreaseDecreaseForPeriodNet': nan,
#  'bs-DebtInstrumentIncreaseDecreaseOtherNet': nan,
#  'bs-DebtInstrumentPeriodicPaymentPrincipal': nan,
#  'bs-DebtInstrumentUnamortizedDiscount': nan,
#  'bs-DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet': nan,
#  'bs-DebtInstrumentUnamortizedDiscountPremiumNet': nan,
#  'bs-DebtIssuanceCostsIncurredDuringNoncashOrPartialNoncashTransaction': nan,
#  'bs-DebtIssuanceCostsLineOfCreditArrangementsNet': nan,
#  'bs-DebtLongtermAndShorttermCombinedAmount': nan,
#  'bs-DebtRelatedCommitmentFeesAndDebtIssuanceCosts': nan,
#  'bs-DebtSecurities': nan,
#  'bs-DebtSecuritiesAvailableForSaleAllowanceForCreditLossNotPreviouslyRecorded': nan,
#  'bs-DebtSecuritiesAvailableForSaleAndHeldToMaturity': nan,
#  'bs-DebtSecuritiesAvailableForSaleChangeInPresentValueExpenseReversal': nan,
#  'bs-DebtSecuritiesAvailableForSaleGainLoss': nan,
#  'bs-DebtSecuritiesAvailableForSaleRealizedGain': nan,
#  'bs-DebtSecuritiesAvailableForSaleRealizedGainLoss': nan,
#  'bs-DebtSecuritiesAvailableForSaleRealizedGainLossExcludingOtherThanTemporaryImpairment': nan,
#  'bs-DebtSecuritiesAvailableForSaleRealizedLoss': nan,
#  'bs-DebtSecuritiesAvailableForSaleUnrealizedGainLoss': nan,
#  'bs-DebtSecuritiesCurrent': nan,
#  'bs-DebtSecuritiesGainLoss': nan,
#  'bs-DebtSecuritiesHeldToMaturityAllowanceForCreditLoss': nan,
#  'bs-DebtSecuritiesHeldToMaturityCreditLossExpenseReversal': nan,
#  'bs-DebtSecuritiesHeldToMaturityPurchase': nan,
#  'bs-DebtSecuritiesHeldToMaturityTransferAmount': nan,
#  'bs-DebtSecuritiesRealizedGainLoss': nan,
#  'bs-DebtSecuritiesRealizedGainLossExcludingOtherThanTemporaryImpairment': nan,
#  'bs-DebtSecuritiesTradingGainLoss': nan,
#  'bs-DebtSecuritiesTradingRestricted': nan,
#  'bs-DebtSecuritiesTradingUnrealizedGainLoss': nan,
#  'bs-DebtSecuritiesUnrealizedGainLoss': nan,
#  'bs-DebtorInPossessionFinancingBorrowingsOutstanding': nan,
#  'bs-DebtorReorganizationItemsGainLossOnAssetSalesNet1': nan,
#  'bs-DecommissioningFundInvestments': nan,
#  'bs-DecommissioningLiabilityNoncurrent': nan,
#  'bs-DecommissioningTrustAssetsAmount': nan,
#  'bs-DeconsolidationGainOrLossAmount': nan,
#  'bs-DecreaseInRestrictedCash': nan,
#  'bs-DeferredCompensationArrangementWithIndividualAllocatedShareBasedCompensationExpense': nan,
#  'bs-DeferredCompensationArrangementWithIndividualCompensationExpense': nan,
#  'bs-DeferredCompensationArrangementWithIndividualRecordedLiability': nan,
#  'bs-DeferredCompensationCashBasedArrangementsLiabilityCurrent': nan,
#  'bs-DeferredCompensationEquity': nan,
#  'bs-DeferredCompensationLiabilityClassifiedNoncurrent': nan,
#  'bs-DeferredCompensationLiabilityCurrent': nan,
#  'bs-DeferredCompensationLiabilityCurrentAndNoncurrent': nan,
#  'bs-DeferredCompensationPlanAssets': nan,
#  'bs-DeferredCompensationShareBasedArrangementsLiabilityCurrent': nan,
#  'bs-DeferredCompensationSharebasedArrangementsLiabilityCurrentAndNoncurrent': nan,
#  'bs-DeferredCosts': nan,
#  'bs-DeferredCostsAndOtherAssets': nan,
#  'bs-DeferredCostsCurrent': nan,
#  'bs-DeferredCostsCurrentAndNoncurrent': nan,
#  'bs-DeferredCostsLeasingGross': nan,
#  'bs-DeferredCostsLeasingNet': nan,
#  'bs-DeferredCostsLeasingNetCurrent': nan,
#  'bs-DeferredCostsLeasingNetNoncurrent': nan,
#  'bs-DeferredCreditsAndOtherLiabilities': nan,
#  'bs-DeferredCreditsAndOtherLiabilitiesCurrent': nan,
#  'bs-DeferredCreditsAndOtherLiabilitiesNoncurrent': nan,
#  'bs-DeferredFederalIncomeTaxExpenseBenefit': nan,
#  'bs-DeferredFederalStateAndLocalTaxExpenseBenefit': nan,
#  'bs-DeferredFinanceCostsCurrentNet': nan,
#  'bs-DeferredFinanceCostsGross': nan,
#  'bs-DeferredFinanceCostsNet': nan,
#  'bs-DeferredFinanceCostsNoncurrentNet': nan,
#  'bs-DeferredFinanceCostsOwnShareLendingArrangementIssuanceCostsAmortizationExpense1': nan,
#  'bs-DeferredForeignIncomeTaxExpenseBenefit': nan,
#  'bs-DeferredFuelCost': nan,
#  'bs-DeferredGainOnSaleOfProperty': nan,
#  'bs-DeferredGasCost': nan,
#  'bs-DeferredGasPurchasesCurrent': nan,
#  'bs-DeferredIncome': nan,
#  'bs-DeferredIncomeCurrent': nan,
#  'bs-DeferredIncomeNoncurrent': nan,
#  'bs-DeferredIncomeTaxAssetsNet': nan,
#  'bs-DeferredIncomeTaxExpenseBenefit': nan,
#  'bs-DeferredIncomeTaxLiabilities': nan,
#  'bs-DeferredIncomeTaxLiabilitiesNet': nan,
#  'bs-DeferredIncomeTaxesAndOtherAssetsCurrent': nan,
#  'bs-DeferredIncomeTaxesAndOtherAssetsNoncurrent': nan,
#  'bs-DeferredIncomeTaxesAndOtherLiabilitiesNoncurrent': nan,
#  'bs-DeferredIncomeTaxesAndOtherTaxLiabilitiesNoncurrent': nan,
#  'bs-DeferredIncomeTaxesAndTaxCredits': nan,
#  'bs-DeferredLongTermLiabilityCharges': nan,
#  'bs-DeferredOfferingCosts': nan,
#  'bs-DeferredOtherTaxExpenseBenefit': nan,
#  'bs-DeferredPolicyAcquisitionCostAmortizationExpense': nan,
#  'bs-DeferredPolicyAcquisitionCosts': nan,
#  'bs-DeferredPolicyAcquisitionCostsAdditions': nan,
#  'bs-DeferredPolicyAcquisitionCostsAndPresentValueOfFutureProfitsAmortization1': nan,
#  'bs-DeferredPolicyAcquisitionCostsAndValueOfBusinessAcquired': nan,
#  'bs-DeferredPolicyAcquisitionCostsPeriodIncreaseDecrease': nan,
#  'bs-DeferredRentAssetNetCurrent': nan,
#  'bs-DeferredRentCredit': nan,
#  'bs-DeferredRentCreditCurrent': nan,
#  'bs-DeferredRentCreditNoncurrent': nan,
#  'bs-DeferredRentReceivablesNet': nan,
#  'bs-DeferredRentReceivablesNetNoncurrent': nan,
#  'bs-DeferredRevenue': nan,
#  'bs-DeferredRevenueAndCreditsCurrent': nan,
#  'bs-DeferredRevenueAndCreditsNoncurrent': nan,
#  'bs-DeferredRevenueCurrent': nan,
#  'bs-DeferredRevenueLeasesCurrent': nan,
#  'bs-DeferredRevenueLeasesGross': nan,
#  'bs-DeferredRevenueLeasesNet': nan,
#  'bs-DeferredRevenueNoncurrent': nan,
#  'bs-DeferredRevenuePeriodIncreaseDecrease': nan,
#  'bs-DeferredSalesInducementsAdditions': nan,
#  'bs-DeferredSalesInducementsAmortizationExpense': nan,
#  'bs-DeferredSalesInducementsNet': nan,
#  'bs-DeferredSalesInducementsPeriodIncreaseDecrease': nan,
#  'bs-DeferredSetUpCostsNoncurrent': nan,
#  'bs-DeferredSubscriberAcquisitionCostsNoncurrent': nan,
#  'bs-DeferredTaxAndOtherLiabilitiesNoncurrent': nan,
#  'bs-DeferredTaxAssetsDeferredIncome': nan,
#  'bs-DeferredTaxAssetsGross': nan,
#  'bs-DeferredTaxAssetsInProcessResearchAndDevelopment': nan,
#  'bs-DeferredTaxAssetsLiabilitiesNet': nan,
#  'bs-DeferredTaxAssetsLiabilitiesNetCurrent': nan,
#  'bs-DeferredTaxAssetsLiabilitiesNetNoncurrent': nan,
#  'bs-DeferredTaxAssetsNet': nan,
#  'bs-DeferredTaxAssetsNetCurrent': nan,
#  'bs-DeferredTaxAssetsNetNoncurrent': nan,
#  'bs-DeferredTaxAssetsOperatingLossCarryforwards': nan,
#  'bs-DeferredTaxAssetsOther': nan,
#  'bs-DeferredTaxExpenseFromStockOptionsExercised': nan,
#  'bs-DeferredTaxLiabilities': nan,
#  'bs-DeferredTaxLiabilitiesCurrent': nan,
#  'bs-DeferredTaxLiabilitiesDeferredExpense': nan,
#  'bs-DeferredTaxLiabilitiesDerivatives': nan,
#  'bs-DeferredTaxLiabilitiesGoodwillAndIntangibleAssetsIntangibleAssets': nan,
#  'bs-DeferredTaxLiabilitiesGrossNoncurrent': nan,
#  'bs-DeferredTaxLiabilitiesNoncurrent': nan,
#  'bs-DeferredTaxLiabilitiesOther': nan,
#  'bs-DeferredTaxLiabilitiesParentsBasisInDiscontinuedOperation': nan,
#  'bs-DeferredTaxLiabilitiesPropertyPlantAndEquipment': nan,
#  'bs-DefinedBenefitPensionPlanCurrentAndNoncurrentLiabilities': nan,
#  'bs-DefinedBenefitPensionPlanLiabilitiesCurrent': nan,
#  'bs-DefinedBenefitPensionPlanLiabilitiesNoncurrent': nan,
#  'bs-DefinedBenefitPlanAccumulatedOtherComprehensiveIncomeBeforeTax': nan,
#  'bs-DefinedBenefitPlanActuarialGainLoss': nan,
#  'bs-DefinedBenefitPlanAmortizationOfPriorServiceCostCredit': nan,
#  'bs-DefinedBenefitPlanAmountsRecognizedInBalanceSheet': nan,
#  'bs-DefinedBenefitPlanAssetsForPlanBenefitsNoncurrent': nan,
#  'bs-DefinedBenefitPlanFundedStatusOfPlan': nan,
#  'bs-DefinedBenefitPlanInterestCost': nan,
#  'bs-DefinedBenefitPlanNetPeriodicBenefitCost': nan,
#  'bs-DefinedBenefitPlanRecognizedNetGainLossDueToSettlements1': nan,
#  'bs-DefinedBenefitPlanRecognizedNetGainLossDueToSettlementsAndCurtailments1': nan,
#  'bs-DefinedBenefitPlanSettlementsBenefitObligation': nan,
#  'bs-DefinedContributionPlanCostRecognized': nan,
#  'bs-DefinedContributionPlanIncreaseDecreaseCost': nan,
#  'bs-DemandDepositAccounts': nan,
#  'bs-Depletion': nan,
#  'bs-DepletionOfOilAndGasProperties': nan,
#  'bs-DepositAssets': nan,
#  'bs-DepositContractsLiabilities': nan,
#  'bs-DepositLiabilitiesAccruedInterest': nan,
#  'bs-DepositLiabilityCurrent': nan,
#  'bs-Deposits': nan,
#  'bs-DepositsAssets': nan,
#  'bs-DepositsAssetsCurrent': nan,
#  'bs-DepositsAssetsNoncurrent': nan,
#  'bs-DepositsDomestic': nan,
#  'bs-DepositsFairValueDisclosure': nan,
#  'bs-DepositsMoneyMarketDeposits': nan,
#  'bs-DepositsMoneyMarketDepositsAndNegotiableOrderOfWithdrawalNOW': nan,
#  'bs-DepositsNegotiableOrderOfWithdrawalNOW': nan,
#  'bs-DepositsOnFlightEquipment': nan,
#  'bs-DepositsRetail': nan,
#  'bs-DepositsSavingsDeposits': nan,
#  'bs-DepositsWholesale': nan,
#  'bs-DepositsWithClearingOrganizationsAndOthersSecurities': nan,
#  'bs-Depreciation': nan,
#  'bs-DepreciationAmortizationAndAccretionNet': nan,
#  'bs-DepreciationAndAmortization': nan,
#  'bs-DepreciationAndAmortizationDiscontinuedOperations': nan,
#  'bs-DepreciationDepletionAndAmortization': nan,
#  'bs-DepreciationNonproduction': nan,
#  'bs-DerivativeAssetFairValueGrossAssetIncludingNotSubjectToMasterNettingArrangement': nan,
#  'bs-DerivativeAssetFairValueGrossLiability': nan,
#  'bs-DerivativeAssetFairValueGrossLiabilityAndObligationToReturnCashOffset': nan,
#  'bs-DerivativeAssetFairValueOfCollateral': nan,
#  'bs-DerivativeAssetFairValueOffsetAgainstCollateralNetOfNotSubjectToMasterNettingArrangementPolicyElection': nan,
#  'bs-DerivativeAssetNotSubjectToMasterNettingArrangementDeduction': nan,
#  'bs-DerivativeAssets': nan,
#  'bs-DerivativeAssetsCurrent': nan,
#  'bs-DerivativeAssetsLiabilitiesAtFairValueNet': nan,
#  'bs-DerivativeAssetsNoncurrent': nan,
#  'bs-DerivativeCollateralObligationToReturnCash': nan,
#  'bs-DerivativeCollateralRightToReclaimCash': nan,
#  'bs-DerivativeCollateralRightToReclaimSecurities': nan,
#  'bs-DerivativeCostOfHedge': nan,
#  'bs-DerivativeFairValueOfDerivativeAsset': nan,
#  'bs-DerivativeFairValueOfDerivativeLiability': nan,
#  'bs-DerivativeFairValueOfDerivativeLiabilityAmountNotOffsetAgainstCollateral': nan,
#  'bs-DerivativeFairValueOfDerivativeLiabilityAmountOffsetAgainstCollateral': nan,
#  'bs-DerivativeGainLossOnDerivativeNet': nan,
#  'bs-DerivativeGainOnDerivative': nan,
#  'bs-DerivativeInstrumentsAndHedges': nan,
#  'bs-DerivativeInstrumentsAndHedgesLiabilities': nan,
#  'bs-DerivativeInstrumentsAndHedgesLiabilitiesNoncurrent': nan,
#  'bs-DerivativeInstrumentsAndHedgesNoncurrent': nan,
#  'bs-DerivativeInstrumentsGainLossReclassifiedFromAccumulatedOCIIntoIncomeEffectivePortionNet': nan,
#  'bs-DerivativeInstrumentsLossReclassifiedFromAccumulatedOCIIntoIncomeEffectivePortion': nan,
#  'bs-DerivativeInstrumentsNotDesignatedAsHedgingInstrumentsGainLossNet': nan,
#  'bs-DerivativeInstrumentsNotDesignatedAsHedgingInstrumentsLiabilityAtFairValue': nan,
#  'bs-DerivativeInstrumentsNotDesignatedAsHedgingInstrumentsLoss': nan,
#  'bs-DerivativeLiabilities': nan,
#  'bs-DerivativeLiabilitiesCurrent': nan,
#  'bs-DerivativeLiabilitiesNoncurrent': nan,
#  'bs-DerivativeLiabilityCollateralRightToReclaimCashOffset': nan,
#  'bs-DerivativeLiabilityFairValueGrossAssetAndRightToReclaimCashOffset': nan,
#  'bs-DerivativeLiabilityFairValueGrossLiabilityIncludingNotSubjectToMasterNettingArrangement': nan,
#  'bs-DerivativeLiabilityFairValueOfCollateral': nan,
#  'bs-DerivativeLiabilityFairValueOffsetAgainstCollateralNetOfNotSubjectToMasterNettingArrangementPolicyElection': nan,
#  'bs-DerivativeLiabilityNotSubjectToMasterNettingArrangementDeduction': nan,
#  'bs-DerivativeLossOnDerivative': nan,
#  'bs-DerivativeNetLiabilityPositionAggregateFairValue': nan,
#  'bs-DevelopmentInProcess': nan,
#  'bs-DirectFinancingLeaseDeferredSellingProfit': nan,
#  'bs-DirectFinancingLeaseLeaseIncome': nan,
#  'bs-DirectFinancingLeaseLeaseReceivable': nan,
#  'bs-DirectFinancingLeaseNetInvestmentInLease': nan,
#  'bs-DirectFinancingLeaseResidualValueOfLeasedAsset': nan,
#  'bs-DirectFinancingLeaseUnguaranteedResidualAsset': nan,
#  'bs-DiscontinuedOperationGainLossFromDisposalOfDiscontinuedOperationBeforeIncomeTax': nan,
#  'bs-DiscontinuedOperationGainLossOnDisposalOfDiscontinuedOperationNetOfTax': nan,
#  'bs-DiscontinuedOperationIncomeLossFromDiscontinuedOperationBeforeIncomeTax': nan,
#  'bs-DiscontinuedOperationIncomeLossFromDiscontinuedOperationDuringPhaseOutPeriodNetOfTax': nan,
#  'bs-DiscontinuedOperationProvisionForLossGainOnDisposalBeforeIncomeTax': nan,
#  'bs-DiscontinuedOperationProvisionForLossGainOnDisposalNetOfTax': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationAccountsNotesAndLoansReceivableNet': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationAccruedIncomeTaxesPayable': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationAccruedLiabilities': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationAssetsNoncurrent': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationCashAndCashEquivalents': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationConsideration': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationDeferredTaxLiabilitiesNoncurrent': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationDepreciationAndAmortization': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationForeignCurrencyTranslationGainsLosses': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationInventory1': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationOtherAssets': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationOtherCurrentAssets': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationOtherCurrentLiabilities': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationOtherLiabilities': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationOtherNoncurrentAssets': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationPropertyPlantAndEquipment': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationPropertyPlantAndEquipmentCurrent': nan,
#  'bs-DisposalGroupIncludingDiscontinuedOperationPropertyPlantAndEquipmentNoncurrent': nan,
#  'bs-DisposalGroupNotDiscontinuedOperationGainLossOnDisposal': nan,
#  'bs-DisposalGroupNotDiscontinuedOperationLossGainOnWriteDown': nan,
#  'bs-DistributedEarnings': nan,
#  'bs-DistributionMadeToLimitedLiabilityCompanyLLCMemberCashDistributionsPaid': nan,
#  'bs-DistributionMadeToLimitedPartnerCashDistributionsDeclared': nan,
#  'bs-DistributionMadeToLimitedPartnerCashDistributionsPaid': nan,
#  'bs-DistributionsOnMandatorilyRedeemableSecurities': nan,
#  'bs-DistributionsPayableToRealEstatePartnerships': nan,
#  'bs-DividendIncomeEquitySecuritiesOperating': nan,
#  'bs-Dividends': nan,
#  'bs-DividendsCash': nan,
#  'bs-DividendsCommonStock': nan,
#  'bs-DividendsCommonStockCash': nan,
#  'bs-DividendsCommonStockPaidinkind': nan,
#  'bs-DividendsCommonStockStock': nan,
#  'bs-DividendsPaidinkind': nan,
#  'bs-DividendsPayableCurrent': nan,
#  'bs-DividendsPayableCurrentAndNoncurrent': nan,
#  'bs-DividendsPreferredStock': nan,
#  'bs-DividendsPreferredStockCash': nan,
#  'bs-DividendsPreferredStockPaidinkind': nan,
#  'bs-DividendsPreferredStockStock': nan,
#  'bs-DividendsReceivable': nan,
#  'bs-DividendsShareBasedCompensation': nan,
#  'bs-DividendsSharebasedCompensationPaidInKind': nan,
#  'bs-DividendsSharebasedCompensationStock': nan,
#  'bs-DividendsStock': nan,
#  'bs-DueFromAffiliateCurrent': nan,
#  'bs-DueFromAffiliateNoncurrent': nan,
#  'bs-DueFromAffiliates': nan,
#  'bs-DueFromBanks': nan,
#  'bs-DueFromCorrespondentBrokers': nan,
#  'bs-DueFromCustomerAcceptances': nan,
#  'bs-DueFromJointVenturesCurrent': nan,
#  'bs-DueFromJointVenturesNoncurrent': nan,
#  'bs-DueFromOfficersOrStockholdersCurrent': nan,
#  'bs-DueFromOfficersOrStockholdersNoncurrent': nan,
#  'bs-DueFromOtherRelatedParties': nan,
#  'bs-DueFromOtherRelatedPartiesCurrent': nan,
#  'bs-DueFromOtherRelatedPartiesNoncurrent': nan,
#  'bs-DueFromRelatedParties': nan,
#  'bs-DueFromRelatedPartiesCurrent': nan,
#  'bs-DueFromRelatedPartiesNoncurrent': nan,
#  'bs-DueToAffiliateCurrent': nan,
#  'bs-DueToAffiliateCurrentAndNoncurrent': nan,
#  'bs-DueToAffiliateNoncurrent': nan,
#  'bs-DueToEmployeesCurrent': nan,
#  'bs-DueToEmployeesNoncurrent': nan,
#  'bs-DueToOfficersOrStockholdersCurrent': nan,
#  'bs-DueToOfficersOrStockholdersCurrentAndNoncurrent': nan,
#  'bs-DueToOfficersOrStockholdersNoncurrent': nan,
#  'bs-DueToOtherRelatedPartiesClassifiedCurrent': nan,
#  'bs-DueToOtherRelatedPartiesCurrentAndNoncurrent': nan,
#  'bs-DueToOtherRelatedPartiesNoncurrent': nan,
#  'bs-DueToRelatedPartiesCurrent': nan,
#  'bs-DueToRelatedPartiesCurrentAndNoncurrent': nan,
#  'bs-DueToRelatedPartiesNoncurrent': nan,
#  'bs-EarlyRepaymentOfSeniorDebt': nan,
#  'bs-EarlyRepaymentOfSubordinatedDebt': nan,
#  'bs-EarnestMoneyDeposits': nan,
#  'bs-EffectOfExchangeRateOnCash': nan,
#  'bs-EffectOfExchangeRateOnCashAndCashEquivalents': nan,
#  'bs-EffectOfExchangeRateOnCashAndCashEquivalentsContinuingOperations': nan,
#  'bs-EffectOfExchangeRateOnCashAndCashEquivalentsDiscontinuedOperations': nan,
#  'bs-EffectOfExchangeRateOnCashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents': nan,
#  'bs-EffectOfExchangeRateOnCashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsDisposalGroupIncludingDiscontinuedOperations': nan,
#  'bs-EffectOfExchangeRateOnCashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations': nan,
#  'bs-EffectOfExchangeRateOnCashDiscontinuedOperations': nan,
#  'bs-EmbeddedDerivativeFairValueOfEmbeddedDerivativeLiability': nan,
#  'bs-EmbeddedDerivativeGainLossOnEmbeddedDerivativeNet': nan,
#  'bs-EmbeddedDerivativeNoLongerBifurcatedAmountReclassifiedToStockholdersEquity': nan,
#  'bs-EmployeeBenefitsAndShareBasedCompensation': nan,
#  'bs-EmployeeBenefitsAndShareBasedCompensationNoncash': nan,
#  'bs-EmployeeRelatedLiabilitiesCurrent': nan,
#  'bs-EmployeeRelatedLiabilitiesCurrentAndNoncurrent': nan,
#  'bs-EmployeeServiceShareBasedCompensationAllocationOfRecognizedPeriodCostsCapitalizedAmount': nan,
#  'bs-EmployeeServiceShareBasedCompensationCashFlowEffectCashUsedToSettleAwards': nan,
#  'bs-EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized': nan,
#  'bs-EmployeeServiceShareBasedCompensationTaxBenefitFromExerciseOfStockOptions': nan,
#  'bs-EmployeeStockOwnershipPlanESOPCashContributionsToESOP': nan,
#  'bs-EmployeeStockOwnershipPlanESOPCompensationExpense': nan,
#  'bs-EmployeeStockOwnershipPlanESOPDeferredShares': nan,
#  'bs-EmployeeStockOwnershipPlanESOPGainLossOnTransactionsInDeferredShares': nan,
#  'bs-EnergyMarketingContractLiabilitiesCurrent': nan,
#  'bs-EnergyMarketingContractsAssetsCurrent': nan,
#  'bs-EnergyMarketingContractsAssetsNoncurrent': nan,
#  'bs-EnergyRelatedInventory': nan,
#  'bs-EnergyRelatedInventoryCoal': nan,
#  'bs-EnergyRelatedInventoryGasStoredUnderground': nan,
#  'bs-EnergyRelatedInventoryNaturalGasInStorage': nan,
#  'bs-EnergyRelatedInventoryOtherFossilFuel': nan,
#  'bs-EnergyRelatedInventoryPropaneGas': nan,
#  'bs-EnvironmentalExpenseAndLiabilities': nan,
#  'bs-EnvironmentalRemediationExpense': nan,
#  'bs-EquipmentExpense': nan,
#  'bs-EquityFairValueAdjustment': nan,
#  'bs-EquityMethodInvestmentAggregateCost': nan,
#  'bs-EquityMethodInvestmentDifferenceBetweenCarryingAmountAndUnderlyingEquity': nan,
#  'bs-EquityMethodInvestmentDividendsOrDistributions': nan,
#  'bs-EquityMethodInvestmentOtherThanTemporaryImpairment': nan,
#  'bs-EquityMethodInvestmentRealizedGainLossOnDisposal': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationAssets': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationCurrentAssets': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationCurrentLiabilities': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationEquity': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationEquityOrCapital': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationLiabilities': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationLiabilitiesAndEquity': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationNetIncomeLoss': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationNoncurrentAssets': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationNoncurrentLiabilities': nan,
#  'bs-EquityMethodInvestmentSummarizedFinancialInformationRevenue': nan,
#  'bs-EquityMethodInvestmentUnderlyingEquityInNetAssets': nan,
#  'bs-EquityMethodInvestments': nan,
#  'bs-EquityRestrictions': nan,
#  'bs-EquitySecuritiesFvNi': nan,
#  'bs-EquitySecuritiesFvNiAndWithoutReadilyDeterminableFairValue': nan,
#  'bs-EquitySecuritiesFvNiCost': nan,
#  'bs-EquitySecuritiesFvNiGainLoss': nan,
#  'bs-EquitySecuritiesFvNiRealizedGainLoss': nan,
#  'bs-EquitySecuritiesFvNiRealizedLoss': nan,
#  'bs-EquitySecuritiesFvNiRestricted': nan,
#  'bs-EquitySecuritiesFvNiUnrealizedGain': nan,
#  'bs-EquitySecuritiesFvNiUnrealizedGainLoss': nan,
#  'bs-EquitySecuritiesFvNiUnrealizedLoss': nan,
#  'bs-EquitySecuritiesWithoutReadilyDeterminableFairValueAmount': nan,
#  'bs-EquitySecuritiesWithoutReadilyDeterminableFairValueImpairmentLossAnnualAmount': nan,
#  'bs-EscrowDeposit': nan,
#  'bs-EscrowDepositDisbursementsRelatedToPropertyAcquisition1': nan,
#  'bs-ExcessTaxBenefitFromShareBasedCompensationFinancingActivities': nan,
#  'bs-ExcessTaxBenefitFromShareBasedCompensationOperatingActivities': nan,
#  'bs-ExplorationAbandonmentAndImpairmentExpense': nan,
#  'bs-ExplorationCosts': nan,
#  'bs-ExplorationCostsCumulative': nan,
#  'bs-ExtinguishmentOfDebtAmount': nan,
#  'bs-ExtinguishmentOfDebtGainLossIncomeTax': nan,
#  'bs-ExtinguishmentOfDebtGainLossNetOfTax': nan,
#  'bs-FDICIndemnificationAssetAccretionOfDiscount': nan,
#  'bs-FIFOInventoryAmount': nan,
#  'bs-FairValueAdjustmentOfWarrants': nan,
#  'bs-FairValueDisclosureOffbalanceSheetRisksAmountLiability': nan,
#  'bs-FairValueDisclosureOffbalanceSheetRisksFaceAmountLiability': nan,
#  'bs-FairValueLiabilitiesMeasuredOnRecurringBasisDebtInstrumentValuationTechniquesChangeInTechniqueQuantificationOfEffect': nan,
#  'bs-FairValueLiabilitiesMeasuredOnRecurringBasisSubordinatedDebtObligations': nan,
#  'bs-FairValueMeasurementWithUnobservableInputsReconciliationRecurringBasisAssetValue': nan,
#  'bs-FairValueMeasurementWithUnobservableInputsReconciliationRecurringBasisLiabilityGainLossIncludedInEarnings': nan,
#  'bs-FairValueMeasurementWithUnobservableInputsReconciliationRecurringBasisLiabilitySettlements': nan,
#  'bs-FairValueNetAssetLiability': nan,
#  'bs-FairValueNetDerivativeAssetLiabilityMeasuredOnRecurringBasisChangeInUnrealizedGainLoss': nan,
#  'bs-FairValueNetDerivativeAssetLiabilityMeasuredOnRecurringBasisUnobservableInputsReconciliationGainLossIncludedInEarnings': nan,
#  'bs-FairValueNetDerivativeAssetLiabilityMeasuredOnRecurringBasisUnobservableInputsReconciliationSettlements': nan,
#  'bs-FairValueNetDerivativeAssetLiabilityRecurringBasisStillHeldUnrealizedGainLossOci': nan,
#  'bs-FairValueOfAssetsAcquired': nan,
#  'bs-FairValueOfSecuritiesReceivedAsCollateralThatHaveBeenResoldOrRepledged': nan,
#  'bs-FairValueOptionChangesInFairValueGainLoss1': nan,
#  'bs-FederalFundsPurchased': nan,
#  'bs-FederalFundsPurchasedAndSecuritiesSoldUnderAgreementsToRepurchase': nan,
#  'bs-FederalFundsSold': nan,
#  'bs-FederalFundsSoldAndSecuritiesPurchasedUnderAgreementsToResell': nan,
#  'bs-FederalHomeLoanBankAdvances': nan,
#  'bs-FederalHomeLoanBankAdvancesBranchOfFHLBBankAmountOfAdvancesByBranch': nan,
#  'bs-FederalHomeLoanBankAdvancesCurrent': nan,
#  'bs-FederalHomeLoanBankAdvancesLongTerm': nan,
#  'bs-FederalHomeLoanBankAdvancesMaturitiesSummaryDueWithinOneYearOfBalanceSheetDate': nan,
#  'bs-FederalHomeLoanBankBorrowingsFairValueDisclosure': nan,
#  'bs-FederalHomeLoanBankConsolidatedObligations': nan,
#  'bs-FederalHomeLoanBankConsolidatedObligationsBonds': nan,
#  'bs-FederalHomeLoanBankConsolidatedObligationsDiscountNotes': nan,
#  'bs-FederalHomeLoanBankStock': nan,
#  'bs-FederalHomeLoanBankStockAndFederalReserveBankStock': nan,
#  'bs-FederalReserveBankStock': nan,
#  'bs-FinanceLeaseImpairmentLoss': nan,
#  'bs-FinanceLeaseInterestExpense': nan,
#  'bs-FinanceLeaseInterestPaymentOnLiability': nan,
#  'bs-FinanceLeaseLiability': nan,
#  'bs-FinanceLeaseLiabilityCurrent': nan,
#  'bs-FinanceLeaseLiabilityNoncurrent': nan,
#  'bs-FinanceLeaseLiabilityPaymentsDue': nan,
#  'bs-FinanceLeaseLiabilityPaymentsDueAfterYearFive': nan,
#  'bs-FinanceLeaseLiabilityPaymentsDueYearFive': nan,
#  'bs-FinanceLeaseLiabilityPaymentsDueYearFour': nan,
#  'bs-FinanceLeaseLiabilityPaymentsDueYearThree': nan,
#  'bs-FinanceLeaseLiabilityPaymentsDueYearTwo': nan,
#  'bs-FinanceLeaseLiabilityPaymentsRemainderOfFiscalYear': nan,
#  'bs-FinanceLeaseLiabilityUndiscountedExcessAmount': nan,
#  'bs-FinanceLeasePrincipalPayments': nan,
#  'bs-FinanceLeaseRightOfUseAsset': nan,
#  'bs-FinanceLeaseRightOfUseAssetAccumulatedAmortization': nan,
#  'bs-FinanceLeaseRightOfUseAssetAmortization': nan,
#  'bs-FinanceLeaseWeightedAverageDiscountRatePercent': nan,
#  'bs-FinancialInstrumentsOwnedAndNotPledgedAtFairValue': nan,
#  'bs-FinancialInstrumentsOwnedAndPledgedAsCollateralAtFairValue': nan,
#  'bs-FinancialInstrumentsOwnedAtFairValue': nan,
#  'bs-FinancialInstrumentsOwnedCorporateEquitiesAtFairValue': nan,
#  'bs-FinancialInstrumentsOwnedMortgagesMortgageBackedAndAssetBackedSecuritiesAtFairValue': nan,
#  'bs-FinancialInstrumentsOwnedOtherAtFairValue': nan,
#  'bs-FinancialInstrumentsOwnedPrincipalInvestmentsAtFairValue': nan,
#  'bs-FinancialInstrumentsOwnedUSGovernmentAndAgencyObligationsAtFairValue': nan,
#  'bs-FinancialInstrumentsSoldNotYetPurchasedAtFairValue': nan,
#  'bs-FinancialInstrumentsSoldNotYetPurchasedUSGovernmentAndAgencyObligations': nan,
#  'bs-FinancialLiabilitiesFairValueDisclosure': nan,
#  'bs-FinancialServicesLiabilities': nan,
#  'bs-FinancingInterestExpense': nan,
#  'bs-FinancingReceivableAfterDeferredIncomeOffset': nan,
#  'bs-FinancingReceivableAllowanceForCreditLosses': nan,
#  'bs-FinancingReceivableAllowanceForCreditLossesWriteOffs': nan,
#  'bs-FinancingReceivableChangeInPresentValueInterestIncome': nan,
#  'bs-FinancingReceivableCoveredAfterAllowanceForCreditLoss': nan,
#  'bs-FinancingReceivableCoveredAllowanceForCreditLoss': nan,
#  'bs-FinancingReceivableCoveredBeforeAllowanceForCreditLoss': nan,
#  'bs-FinancingReceivableModificationsRecordedInvestment': nan,
#  'bs-FinancingReceivableReclassificationToHeldForSale': nan,
#  'bs-FinancingReceivableSignificantSales': nan,
#  'bs-FiniteLivedCoreDepositsGross': nan,
#  'bs-FiniteLivedCustomerRelationshipsGross': nan,
#  'bs-FiniteLivedIntangibleAssetAcquiredInPlaceLeases': nan,
#  'bs-FiniteLivedIntangibleAssetOffMarketLeaseFavorableGross': nan,
#  'bs-FiniteLivedIntangibleAssetsAccumulatedAmortization': nan,
#  'bs-FiniteLivedIntangibleAssetsAmortizationExpenseAfterYearFive': nan,
#  'bs-FiniteLivedIntangibleAssetsAmortizationExpenseRemainderOfFiscalYear': nan,
#  'bs-FiniteLivedIntangibleAssetsAmortizationExpenseYearFive': nan,
#  'bs-FiniteLivedIntangibleAssetsAmortizationExpenseYearFour': nan,
#  'bs-FiniteLivedIntangibleAssetsAmortizationExpenseYearThree': nan,
#  'bs-FiniteLivedIntangibleAssetsAmortizationExpenseYearTwo': nan,
#  'bs-FiniteLivedIntangibleAssetsGross': nan,
#  'bs-FiniteLivedIntangibleAssetsNet': nan,
#  'bs-FiniteLivedLicenseAgreementsGross': nan,
#  'bs-FiniteLivedPatentsGross': nan,
#  'bs-FiniteLivedTradeNamesGross': nan,
#  'bs-FiniteLivedTrademarksGross': nan,
#  'bs-FinitelivedIntangibleAssetsAcquired1': nan,
#  'bs-FixturesAndEquipmentGross': nan,
#  'bs-FlightEquipmentGross': nan,
#  'bs-FlightEquipmentNet': nan,
#  'bs-ForeclosedAssets': nan,
#  'bs-ForeclosedRealEstateExpense': nan,
#  'bs-ForeignCurrencyContractAssetFairValueDisclosure': nan,
#  'bs-ForeignCurrencyContractsLiabilityFairValueDisclosure': nan,
#  'bs-ForeignCurrencyExchangeRateTranslation1': nan,
#  'bs-ForeignCurrencyTransactionGainBeforeTax': nan,
#  'bs-ForeignCurrencyTransactionGainLossBeforeTax': nan,
#  'bs-ForeignCurrencyTransactionGainLossRealized': nan,
#  'bs-ForeignCurrencyTransactionGainLossUnrealized': nan,
#  'bs-ForeignCurrencyTransactionLossBeforeTax': nan,
#  'bs-FundsHeldForClients': nan,
#  'bs-FundsHeldUnderReinsuranceAgreementsAsset': nan,
#  'bs-FundsHeldUnderReinsuranceAgreementsLiability': nan,
#  'bs-FurnitureAndFixturesGross': nan,
#  'bs-GainLossFromPriceRiskManagementActivity': nan,
#  'bs-GainLossOnCashFlowHedgeIneffectivenessNet': nan,
#  'bs-GainLossOnCondemnation': nan,
#  'bs-GainLossOnContractTermination': nan,
#  'bs-GainLossOnDerivativeInstrumentsHeldForTradingPurposesNet': nan,
#  'bs-GainLossOnDerivativeInstrumentsNetPretax': nan,
#  'bs-GainLossOnDiscontinuationOfInterestRateCashFlowHedgeDueToForecastedTransactionProbableOfNotOccurringNet': nan,
#  'bs-GainLossOnDispositionOfAssets': nan,
#  'bs-GainLossOnDispositionOfAssets1': nan,
#  'bs-GainLossOnDispositionOfIntangibleAssets': nan,
#  'bs-GainLossOnDispositionOfOtherFinancialAssets': nan,
#  'bs-GainLossOnDispositionOfRealEstateDiscontinuedOperations': nan,
#  'bs-GainLossOnForeignCurrencyCashFlowHedgeIneffectiveness': nan,
#  'bs-GainLossOnForeignCurrencyDerivativeInstrumentsNotDesignatedAsHedgingInstruments': nan,
#  'bs-GainLossOnInterestRateDerivativeInstrumentsNotDesignatedAsHedgingInstruments': nan,
#  'bs-GainLossOnInvestments': nan,
#  'bs-GainLossOnInvestmentsExcludingOtherThanTemporaryImpairments': nan,
#  'bs-GainLossOnOilAndGasHedgingActivity': nan,
#  'bs-GainLossOnPriceRiskDerivativeInstrumentsNotDesignatedAsHedgingInstruments': nan,
#  'bs-GainLossOnRepurchaseOfDebtInstrument': nan,
#  'bs-GainLossOnSaleOfBusiness': nan,
#  'bs-GainLossOnSaleOfCapitalLeasesNet': nan,
#  'bs-GainLossOnSaleOfCommodityContracts': nan,
#  'bs-GainLossOnSaleOfDebtInvestments': nan,
#  'bs-GainLossOnSaleOfDerivatives': nan,
#  'bs-GainLossOnSaleOfEquityInvestments': nan,
#  'bs-GainLossOnSaleOfInsuranceBlock': nan,
#  'bs-GainLossOnSaleOfInterestInProjects': nan,
#  'bs-GainLossOnSaleOfInvestments': nan,
#  'bs-GainLossOnSaleOfLeasedAssetsNetOperatingLeases': nan,
#  'bs-GainLossOnSaleOfLoansAndLeases': nan,
#  'bs-GainLossOnSaleOfMortgageLoans': nan,
#  'bs-GainLossOnSaleOfNotesReceivable': nan,
#  'bs-GainLossOnSaleOfOilAndGasProperty': nan,
#  'bs-GainLossOnSaleOfOtherAssets': nan,
#  'bs-GainLossOnSaleOfOtherInvestments': nan,
#  'bs-GainLossOnSaleOfOtherLoansAndLeases': nan,
#  'bs-GainLossOnSaleOfPreviouslyUnissuedStockBySubsidiaryOrEquityInvesteeNonoperatingIncome': nan,
#  'bs-GainLossOnSaleOfProperties': nan,
#  'bs-GainLossOnSaleOfPropertiesBeforeApplicableIncomeTaxes': nan,
#  'bs-GainLossOnSaleOfPropertiesNetOfApplicableIncomeTaxes': nan,
#  'bs-GainLossOnSaleOfProperty': nan,
#  'bs-GainLossOnSaleOfPropertyPlantEquipment': nan,
#  'bs-GainLossOnSaleOfProvedProperty': nan,
#  'bs-GainLossOnSaleOfStockInSubsidiaryOrEquityMethodInvestee': nan,
#  'bs-GainLossOnSaleOfTrustAssetsToPayExpenses': nan,
#  'bs-GainLossOnSalesOfAssetsAndAssetImpairmentCharges': nan,
#  'bs-GainLossOnSalesOfConsumerLoans': nan,
#  'bs-GainLossOnSalesOfLoansNet': nan,
#  ...}
